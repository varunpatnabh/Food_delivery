# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('test.csv',na_values=['NaN '])
df.head(2)
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x2318    COIMBRES13DEL01                   NaN                      NaN
# 1  0x3474     BANGRES15DEL01                  28.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.003669             76.976494                   11.043669
# 1            12.975377             77.696664                   13.085377
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    77.016494  30-03-2022         NaN          15:05:00
# 1                    77.806664  29-03-2022    20:30:00          20:35:00
#
#   Weatherconditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0    conditions NaN                  NaN                  3       Drinks
# 1  conditions Windy                 Jam                   0        Snack
#
#      Type_of_vehicle  multiple_deliveries Festival            City
# ...

# %%
df.dropna(inplace = True)
#df[['Delivery_location_latitude']]
df
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 1      0x3474     BANGRES15DEL01                  28.0
# 2      0x9420      JAPRES09DEL03                  23.0
# 3      0x72ee      JAPRES07DEL03                  21.0
# 4      0xa759     CHENRES19DEL01                  31.0
# 5      0xc4af      GOARES04DEL01                  26.0
# ...        ...                ...                  ...
# 11393  0xe240      BHPRES07DEL01                  31.0
# 11394  0x6909      JAPRES01DEL01                  35.0
# 11395  0x443b      JAPRES11DEL01                  33.0
# 11397  0x22d4      VADRES03DEL02                  27.0
# 11398  0xb7be     CHENRES07DEL02                  39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# 3                          4.8            26.766536             75.837333
# ...

# %%
df = df.assign(new_col= df['Delivery_person_Age']/df['Delivery_person_Ratings'])
#df[['new_col']]
df
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 1      0x3474     BANGRES15DEL01                  28.0
# 2      0x9420      JAPRES09DEL03                  23.0
# 3      0x72ee      JAPRES07DEL03                  21.0
# 4      0xa759     CHENRES19DEL01                  31.0
# 5      0xc4af      GOARES04DEL01                  26.0
# ...        ...                ...                  ...
# 11393  0xe240      BHPRES07DEL01                  31.0
# 11394  0x6909      JAPRES01DEL01                  35.0
# 11395  0x443b      JAPRES11DEL01                  33.0
# 11397  0x22d4      VADRES03DEL02                  27.0
# 11398  0xb7be     CHENRES07DEL02                  39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# 3                          4.8            26.766536             75.837333
# ...

# %%
#df.sort_values(by = 'new_col',ascending = False)
df[['new_col']].sort_values(by = 'new_col',ascending = False)
# Out:
#          new_col
# 1439   11.818182
# 8106   11.600000
# 10448  11.600000
# 411    11.470588
# 6499   11.290323
# ...          ...
# 10595   4.000000
# 6332    4.000000
# 8734    4.000000
# 6162    4.000000
# 372     4.000000
#
# [10291 rows x 1 columns]

# %%
#df[(df['Delivery_person_Age']>=35) & (df['Delivery_person_Ratings'] < 4)].sort_values(by = 'Delivery_person_Age')
df[(df.Delivery_person_Age>35)& (df['Delivery_person_Ratings']<4)].sort_values(by ='Delivery_person_Ratings')
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 1439   0xcc3a      ALHRES01DEL01                  39.0
# 6707   0x5cc8     INDORES11DEL03                  36.0
# 411    0x88f0      HYDRES19DEL02                  39.0
# 10137  0x26f8      VADRES06DEL02                  37.0
# 3188   0xb390   RANCHIRES03DEL02                  37.0
# ...        ...                ...                  ...
# 6468   0x8611     INDORES04DEL01                  39.0
# 7424   0x1028      MYSRES15DEL01                  37.0
# 8159   0x5b81     CHENRES08DEL02                  37.0
# 1550    0xdbb     CHENRES04DEL01                  38.0
# 2865   0xbd30   RANCHIRES15DEL02                  36.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1439                       3.3            25.454648             81.834502
# 6707                       3.3            22.751234             75.889490
# 411                        3.4            17.458998             78.500366
# ...

# %%
df[df['Delivery_person_Age'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weatherconditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, new_col]
# Index: []

# %%
#df[df.Delivery_person_Age > df.Delivery_person_Ratings]
df[df['Delivery_person_Age']>df['Delivery_person_Ratings']]
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 1      0x3474     BANGRES15DEL01                  28.0
# 2      0x9420      JAPRES09DEL03                  23.0
# 3      0x72ee      JAPRES07DEL03                  21.0
# 4      0xa759     CHENRES19DEL01                  31.0
# 5      0xc4af      GOARES04DEL01                  26.0
# ...        ...                ...                  ...
# 11393  0xe240      BHPRES07DEL01                  31.0
# 11394  0x6909      JAPRES01DEL01                  35.0
# 11395  0x443b      JAPRES11DEL01                  33.0
# 11397  0x22d4      VADRES03DEL02                  27.0
# 11398  0xb7be     CHENRES07DEL02                  39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# 3                          4.8            26.766536             75.837333
# ...

# %%
df[df['Delivery_person_ID'].str.contains('C')]
# Out:
#             ID  Delivery_person_ID  Delivery_person_Age  \
# 4      0xa759      CHENRES19DEL01                  31.0
# 10     0xd845       KOCRES09DEL01                  24.0
# 12     0x4598    RANCHIRES14DEL03                  35.0
# 14     0x73ec   RANCHIRES010DEL03                  36.0
# 16     0x9fa6     COIMBRES03DEL03                  38.0
# ...        ...                 ...                  ...
# 11372  0x104b      CHENRES09DEL03                  32.0
# 11381  0x95dc     COIMBRES07DEL02                  36.0
# 11382  0x2114      CHENRES12DEL01                  21.0
# 11387  0x77fe      CHENRES01DEL01                  33.0
# 11398  0xb7be      CHENRES07DEL02                  39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 4                          4.6            12.986047             80.218114
# 10                         4.8            10.000706             76.349516
# ...

# %%
#df[df['Delivery_person_ID'].str.contains('MB|EN',regex= True)].count()
df['Delivery_person_ID'].str.contains('MB|EN',regex= True).count()
# Out:
# 10291

# %%
df[df['Delivery_person_ID'].str.startswith('M',na = True)] ###
#df['Delivery_person_ID'].str.startswith('M',na = True) ###
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 8      0x872b      MYSRES05DEL03                  35.0
# 28     0x87a1      MYSRES03DEL01                  29.0
# 45     0x869f      MYSRES13DEL01                  30.0
# 52     0x5571      MYSRES02DEL02                  21.0
# 61     0xb986      MYSRES04DEL02                  20.0
# ...        ...                ...                  ...
# 11361  0x4510      MYSRES15DEL01                  31.0
# 11362  0x37ca      MYSRES19DEL01                  29.0
# 11363  0x9eb4      MUMRES18DEL01                  38.0
# 11368  0x5f99      MYSRES01DEL02                  32.0
# 11377  0x3ecb      MUMRES18DEL02                  34.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 8                          4.9            12.323978             76.627961
# 28                         4.7            12.299524             76.642620
# 45                         4.4            12.310972             76.659264
# ...

# %%
df[df['Delivery_person_ID'].astype(str).str.endswith(' ',na = False)]
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 1      0x3474     BANGRES15DEL01                  28.0
# 2      0x9420      JAPRES09DEL03                  23.0
# 3      0x72ee      JAPRES07DEL03                  21.0
# 4      0xa759     CHENRES19DEL01                  31.0
# 5      0xc4af      GOARES04DEL01                  26.0
# ...        ...                ...                  ...
# 11393  0xe240      BHPRES07DEL01                  31.0
# 11394  0x6909      JAPRES01DEL01                  35.0
# 11395  0x443b      JAPRES11DEL01                  33.0
# 11397  0x22d4      VADRES03DEL02                  27.0
# 11398  0xb7be     CHENRES07DEL02                  39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# 3                          4.8            26.766536             75.837333
# ...

# %%
df[(df['Delivery_person_Age'] == 35.0 ) & (df['Delivery_person_Ratings'] >4.5)]
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 8      0x872b      MYSRES05DEL03                  35.0
# 12     0x4598   RANCHIRES14DEL03                  35.0
# 41     0xa6ba      HYDRES01DEL03                  35.0
# 48     0x4981     CHENRES02DEL03                  35.0
# 79     0xdb61      BHPRES12DEL03                  35.0
# ...        ...                ...                  ...
# 11264  0x25dc     INDORES17DEL03                  35.0
# 11273  0x43b1      JAPRES17DEL02                  35.0
# 11281  0x60f4      JAPRES20DEL03                  35.0
# 11333  0x7cc7      MYSRES07DEL01                  35.0
# 11394  0x6909      JAPRES01DEL01                  35.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 8                          4.9            12.323978             76.627961
# 12                         4.8             0.000000              0.000000
# 41                         4.7            17.410371             78.437225
# ...

# %%
df[df['Delivery_person_Ratings'].isin([4.8,4.5,4.7])]
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 2      0x9420      JAPRES09DEL03                  23.0
# 3      0x72ee      JAPRES07DEL03                  21.0
# 5      0xc4af      GOARES04DEL01                  26.0
# 6      0x3b9d     BANGRES19DEL02                  23.0
# 7      0xdd42      KOLRES06DEL02                  26.0
# ...        ...                ...                  ...
# 11381  0x95dc    COIMBRES07DEL02                  36.0
# 11384  0xd661      GOARES01DEL03                  37.0
# 11391  0xd3de     LUDHRES07DEL03                  26.0
# 11393  0xe240      BHPRES07DEL01                  31.0
# 11397  0x22d4      VADRES03DEL02                  27.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 2                          4.5            26.911378             75.789034
# 3                          4.8            26.766536             75.837333
# 5                          4.7            15.569600             73.742294
# ...

# %%
df[df['Delivery_person_Ratings'].between(4.2,4.8)]
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 1      0x3474     BANGRES15DEL01                  28.0
# 2      0x9420      JAPRES09DEL03                  23.0
# 3      0x72ee      JAPRES07DEL03                  21.0
# 4      0xa759     CHENRES19DEL01                  31.0
# 5      0xc4af      GOARES04DEL01                  26.0
# ...        ...                ...                  ...
# 11388  0x2a31      SURRES19DEL02                  39.0
# 11391  0xd3de     LUDHRES07DEL03                  26.0
# 11393  0xe240      BHPRES07DEL01                  31.0
# 11394  0x6909      JAPRES01DEL01                  35.0
# 11397  0x22d4      VADRES03DEL02                  27.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# 3                          4.8            26.766536             75.837333
# ...

# %%
df.groupby('Weatherconditions').size()
# Out:
# Weatherconditions
# conditions Cloudy        1718
# conditions Fog           1636
# conditions Sandstorms    1722
# conditions Stormy        1667
# conditions Sunny         1769
# conditions Windy         1779
# dtype: int64

# %%
df[df['Delivery_location_longitude']<=10].index## to find the index with the given conditions
# Out:
# Int64Index([   12,    43,    66,    74,    79,    96,    99,   102,   117,
#               134,
#             ...
#             11282, 11297, 11301, 11304, 11307, 11355, 11356, 11383, 11391,
#             11393],
#            dtype='int64', length=771)

# %%
df.groupby(['Weatherconditions','Road_traffic_density']).size()
# Out:
# Weatherconditions      Road_traffic_density
# conditions Cloudy      High                    162
#                        Jam                     564
#                        Low                     583
#                        Medium                  409
# conditions Fog         High                    141
#                        Jam                     543
#                        Low                     563
#                        Medium                  389
# conditions Sandstorms  High                    169
#                        Jam                     539
#                        Low                     573
#                        Medium                  441
# conditions Stormy      High                    193
#                        Jam                     485
#                        Low                     574
#                        Medium                  415
# conditions Sunny       High                    173
#                        Jam                     558
# ...

# %%
df["Road_traffic_density"][1]
# Out:
# 'Jam '

# %%
df[(df['Weatherconditions'] =='conditions Windy') & (df['Road_traffic_density'] =='Jam ')].sort_values(by = 'Delivery_person_Age').iloc[:1]
#df[(df['Delivery_person_Age']==35) & (df['Delivery_person_Ratings'] ==3.9)].sort_values(by = 'Delivery_person_Age').iloc[1:2]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 5485  0x8c0d      MUMRES12DEL01                  20.0
#
#       Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 5485                      4.9            19.207222             72.972281
#
#       Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 5485                   19.317222                    73.082281  06-04-2022
#
#      Time_Orderd Time_Order_picked Weatherconditions Road_traffic_density  \
# 5485    20:35:00          20:50:00  conditions Windy                 Jam
#
#       Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 5485                  2       Buffet         scooter                   0.0
#
#      Festival            City   new_col
# 5485      No   Metropolitian   4.081633

# %%
df.groupby('Weatherconditions').agg({'Delivery_person_Ratings':np.mean,'Weatherconditions':np.size})
# Out:
#                        Delivery_person_Ratings  Weatherconditions
# Weatherconditions
# conditions Cloudy                     4.658091               1718
# conditions Fog                        4.655379               1636
# conditions Sandstorms                 4.608595               1722
# conditions Stormy                     4.613437               1667
# conditions Sunny                      4.637479               1769
# conditions Windy                      4.608094               1779

# %%
df.groupby(['Weatherconditions','Road_traffic_density']).agg({'Delivery_person_Ratings':[np.size,np.mean]})
# Out:
#                                            Delivery_person_Ratings
#                                                               size      mean
# Weatherconditions     Road_traffic_density
# conditions Cloudy     High                                     162  4.650000
#                       Jam                                      564  4.629433
#                       Low                                      583  4.682504
#                       Medium                                   409  4.666015
# conditions Fog        High                                     141  4.629787
#                       Jam                                      543  4.619890
#                       Low                                      563  4.685080
#                       Medium                                   389  4.671208
# conditions Sandstorms High                                     169  4.644970
#                       Jam                                      539  4.539703
# ...

# %%
g = df.groupby('Weatherconditions')
g.filter(lambda x: len(x)>1700)['Weatherconditions'].value_counts()
# Out:
# conditions Windy         1779
# conditions Sunny         1769
# conditions Sandstorms    1722
# conditions Cloudy        1718
# Name: Weatherconditions, dtype: int64

# %%
##join, merger

# %%
pd.merge(df1,df2,on = 'key')# by default it will take inner join i.e will take the matching cell

# %%
#how ='outer' will give all the matcching and non matching

# %%
lim = 2
offset = 5
df.sort_values('Weatherconditions').iloc[offset:lim+offset]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 7060  0x3610    COIMBRES19DEL01                  33.0
# 7059  0x29bd      HYDRES14DEL03                  39.0
#
#       Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 7060                      4.7            11.022298             76.998349
# 7059                      4.6            17.426228             78.407495
#
#       Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 7060                   11.092298                    77.068349  31-03-2022
# 7059                   17.516228                    78.497495  04-04-2022
#
#      Time_Orderd Time_Order_picked  Weatherconditions Road_traffic_density  \
# 7060    19:10:00          19:15:00  conditions Cloudy                 Jam
# 7059    21:50:00          22:05:00  conditions Cloudy                 Jam
#
#       Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# ...

# %%
df[df['Weatherconditions']=='conditions Cloudy']
# Out:
#             ID Delivery_person_ID  Delivery_person_Age  \
# 8      0x872b      MYSRES05DEL03                  35.0
# 15     0x5ca7      HYDRES19DEL03                  34.0
# 18     0x36e5     CHENRES20DEL03                  37.0
# 21      0xa65     PUNERES03DEL02                  31.0
# 29     0xb64c    COIMBRES01DEL02                  21.0
# ...        ...                ...                  ...
# 11376  0xb790      HYDRES05DEL03                  31.0
# 11381  0x95dc    COIMBRES07DEL02                  36.0
# 11384  0xd661      GOARES01DEL03                  37.0
# 11388  0x2a31      SURRES19DEL02                  39.0
# 11391  0xd3de     LUDHRES07DEL03                  26.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 8                          4.9            12.323978             76.627961
# 15                         4.6            17.458998             78.500366
# 18                         4.7            12.975996             80.221898
# ...

# %%
# import pandas package as pd
import pandas as pd

# Define a dictionary containing students data
data = {'Name': ['Sneha', 'Shreya',
				'Sabhya', 'Riya'],
		'Age': [22, 18, 10, 19],
		'Stream': ['Computer', 'Commerce',
				'Arts', 'Mechanical'],
		'Percentage': [89, 93, 97, 73]}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data, columns=['Name', 'Age',
								'Stream', 'Percentage'])

print("Given Dataframe :\n", df)

print("\nIterating over rows using iterrows() method :\n")

# iterate through each row and select
# 'Name' and 'Age' columns respectively.
for index,row in df.iterrows():
	print(row["Name"], row["Age"])
# Out:
# Given Dataframe :
#       Name  Age      Stream  Percentage
# 0   Sneha   22    Computer          89
# 1  Shreya   18    Commerce          93
# 2  Sabhya   10        Arts          97
# 3    Riya   19  Mechanical          73
#
# Iterating over rows using iterrows() method :
#
# Sneha 22
# Shreya 18
# Sabhya 10
# Riya 19

# %%
for row in df.itertuples(index=True, name='Pandas'):
    print(getattr(row, "Name"), getattr(row, "Percentage"))
# Out:
# Sneha 89
# Shreya 93
# Sabhya 97
# Riya 73

# %%
df.loc[len(df.index)] = ['Alex', 19,'syz', 93] ### insert a new row
df['new_col']=[2,3,4,5,6,2]

# %%
df.insert(2, "Address", ['Chicago', 'London', 'Berlin','Chicago', 'London', 'Berlin'], True)

# %%
df['ffgsd']=''
df
# Out:
#      Name  Age  Address      Stream  Percentage  new_col ffgsd
# 0   Sneha   22  Chicago    Computer          89        2
# 1  Shreya   18   London    Commerce          93        3
# 2  Sabhya   10   Berlin        Arts          97        4
# 3    Riya   19  Chicago  Mechanical          73        5
# 4    Alex   19   London         syz          93        6
# 5    Alex   19   Berlin         syz          93        2

# %%
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df2 = pd.DataFrame({'A': [3, 4, 5], 'C': [7, 8, 9]})
print(df1)
print(df2)
merged_df = pd.merge(df1, df2, on='A')
print(merged_df)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    A  C
# 0  3  7
# 1  4  8
# 2  5  9
#    A  B  C
# 0  3  6  7

# %%
import pandas as pd

df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index=['a', 'b', 'c'])
df2 = pd.DataFrame({'C': [7, 8, 9]}, index=['a', 'b', 'c'])
print(df1)
print(df2)
joined_df = df1.join(df2)
print(joined_df)
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6
#    C
# a  7
# b  8
# c  9
#    A  B  C
# a  1  4  7
# b  2  5  8
# c  3  6  9
